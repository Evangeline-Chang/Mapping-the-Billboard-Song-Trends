# %% [markdown]
# # Sentiment Analysis on Lyrics by Genre
# 2023-04-21<br>
# Evangeline Chang

# %%
# %pip install xlrd
# Out:
# Requirement already satisfied: xlrd in /Users/evangeline/opt/anaconda3/lib/python3.9/site-packages (2.0.1)
# DEPRECATION: pyodbc 4.0.0-unsupported has a non-standard version number. pip 24.0 will enforce this behaviour change. A possible replacement is to upgrade to a newer version of pyodbc or contact the author to suggest that they release a version with a conforming version number. Discussion can be found at https://github.com/pypa/pip/issues/12063
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import re
import xlrd
import numpy as np
import string
from nltk.corpus import stopwords
from nltk.stem import PorterStemmer
from nltk.tokenize import TweetTokenizer

import warnings
warnings.filterwarnings("ignore")

# %%
all_lyrics = pd.read_excel('data/RQ1/lyrics1.xlsx')

# %%
# data cleaning
all_lyrics['lyrics'] = all_lyrics['lyrics'].apply(lambda x: re.sub(r'^.*?Lyrics', '', str(x)))
all_lyrics['lyrics'] = all_lyrics['lyrics'].apply(lambda x: re.sub(r'\[(.*?)\]', '', str(x)))
all_lyrics['lyrics'] = all_lyrics['lyrics'].apply(lambda x: re.sub(r'\n', ' ', str(x)))
all_lyrics['lyrics'] = all_lyrics['lyrics'].apply(lambda x: re.sub(r'\d+Embed', '', str(x)))

all_lyrics['genres'] = all_lyrics['genres'].fillna('').apply(lambda x: str(x).lower())

all_lyrics.head()
# Out:
#    year  No.            Title                Artist(s)  \
# 0  2003    1     "In da Club"                  50 Cent
# 1  2003    2       "Ignition"                 R. Kelly
# 2  2003    3       "Get Busy"                Sean Paul
# 3  2003    4  "Crazy in Love"  Beyoncé featuring Jay-Z
# 4  2003    5  "When I'm Gone"             3 Doors Down
#
#                                               lyrics  \
# 0     Go, go Go, go, go, go Go, shawty, it's your...
# 1   You remind me of something I just can't think...
# 2   Shake dat ting, miss Cana, Cana Shake dat tin...
# 3   Yes! (Whoo, ow!) So crazy right now Most incr...
# 4   Yeah, it's my life In my own words, I guess  ...
#
#                             genres  \
# 0                          hip hop
# 1
# 2  pop, world/traditional, hip hop
# 3                pop, hip hop, r&b
# 4                       metal, pop
#
#                                            subgenres      time
# 0  east coast hip hop, gangster rap, hip hop, pop...  03:13:00
# 1                                                NaN  03:06:00
# 2                      dance pop, dancehall, pop rap  03:31:00
# 3  dance pop, pop, r&b, east coast hip hop, hip h...  03:56:00
# 4  alternative metal, nu metal, pop rock, post-gr...  04:20:00

# %%
df = all_lyrics[["lyrics"]]
df.head()
# Out:
#                                               lyrics
# 0     Go, go Go, go, go, go Go, shawty, it's your...
# 1   You remind me of something I just can't think...
# 2   Shake dat ting, miss Cana, Cana Shake dat tin...
# 3   Yes! (Whoo, ow!) So crazy right now Most incr...
# 4   Yeah, it's my life In my own words, I guess  ...

# %%
df1 = df.copy()
df2 = df.copy()

# %% [markdown]
# ## TextBlob

# %%
from textblob import TextBlob

# %%
for index, row in df1.iterrows():
    lyrics = row['lyrics']
    analysis = TextBlob(lyrics)
    df1.at[index, 'polarity'] = analysis.sentiment[0]
    df1.at[index, 'subjectivity'] = analysis.sentiment[1]
    if analysis.sentiment[0] > 0:
        df1.at[index, 'Sentiment'] = "Positive"
    elif analysis.sentiment[0] < 0:
        df1.at[index, 'Sentiment'] = "Negative"
    else:
        df1.at[index, 'Sentiment'] = "Neutral"

# %%
df1.head()
# Out:
#                                               lyrics  polarity  subjectivity  \
# 0     Go, go Go, go, go, go Go, shawty, it's your...  0.144514      0.577083
# 1   You remind me of something I just can't think... -0.083840      0.408799
# 2   Shake dat ting, miss Cana, Cana Shake dat tin...  0.316818      0.457500
# 3   Yes! (Whoo, ow!) So crazy right now Most incr...  0.018005      0.643786
# 4   Yeah, it's my life In my own words, I guess  ...  0.095136      0.385112
#
#   Sentiment
# 0  Positive
# 1  Negative
# 2  Positive
# 3  Positive
# 4  Positive

# %% [markdown]
# ## VADER

# %%
import nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     /Users/evangeline/nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
for index, row in df2.iterrows():
    score = SentimentIntensityAnalyzer().polarity_scores(row['lyrics'])
    if score['neg'] > score['pos']:
        df2.loc[index, "Sentiment"] = "Negative"
    elif score['pos'] > score['neg']:
        df2.loc[index, "Sentiment"] = "Positive"
    else:
        df2.loc[index, "Sentiment"] = "Neutral"
        
    df2.loc[index, 'neg'] = score['neg']
    df2.loc[index, 'neu'] = score['neu']
    df2.loc[index, 'pos'] = score['pos']
    df2.loc[index, 'compound'] = score['compound']

# %%
df2.head()
# Out:
#                                               lyrics Sentiment    neg    neu  \
# 0     Go, go Go, go, go, go Go, shawty, it's your...  Negative  0.110  0.794
# 1   You remind me of something I just can't think...  Negative  0.054  0.911
# 2   Shake dat ting, miss Cana, Cana Shake dat tin...  Positive  0.082  0.807
# 3   Yes! (Whoo, ow!) So crazy right now Most incr...  Negative  0.161  0.717
# 4   Yeah, it's my life In my own words, I guess  ...  Positive  0.086  0.788
#
#      pos  compound
# 0  0.096   -0.9618
# 1  0.035   -0.9375
# 2  0.111    0.9873
# 3  0.121   -0.9654
# 4  0.125    0.9896

# %% [markdown]
# ## Comparison

# %%
df1.rename(columns={'Sentiment': 'Textblob'}, inplace=True)
df1.rename(columns={'polarity': 'TB_Polarity','subjectivity':'TB_Subjectivity'}, inplace=True)
df1.head()
# Out:
#                                               lyrics  TB_Polarity  \
# 0     Go, go Go, go, go, go Go, shawty, it's your...     0.144514
# 1   You remind me of something I just can't think...    -0.083840
# 2   Shake dat ting, miss Cana, Cana Shake dat tin...     0.316818
# 3   Yes! (Whoo, ow!) So crazy right now Most incr...     0.018005
# 4   Yeah, it's my life In my own words, I guess  ...     0.095136
#
#    TB_Subjectivity  Textblob
# 0         0.577083  Positive
# 1         0.408799  Negative
# 2         0.457500  Positive
# 3         0.643786  Positive
# 4         0.385112  Positive

# %%
df2.rename(columns={'Sentiment':'Vader', 'compound':'VD_Polarity'},inplace=True)
df2.drop(['lyrics'], axis=1, inplace=True)
df2.head()
# Out:
#       Vader    neg    neu    pos  VD_Polarity
# 0  Negative  0.110  0.794  0.096      -0.9618
# 1  Negative  0.054  0.911  0.035      -0.9375
# 2  Positive  0.082  0.807  0.111       0.9873
# 3  Negative  0.161  0.717  0.121      -0.9654
# 4  Positive  0.086  0.788  0.125       0.9896

# %%
pdList = [df1, df2]
df_comp = pd.concat((pdList), axis=1)

df_comp = df_comp[["lyrics", "Textblob", "Vader", "TB_Polarity", "VD_Polarity", "neg"]]
df_comp.head()
# Out:
#                                               lyrics  Textblob     Vader  \
# 0     Go, go Go, go, go, go Go, shawty, it's your...  Positive  Negative
# 1   You remind me of something I just can't think...  Negative  Negative
# 2   Shake dat ting, miss Cana, Cana Shake dat tin...  Positive  Positive
# 3   Yes! (Whoo, ow!) So crazy right now Most incr...  Positive  Negative
# 4   Yeah, it's my life In my own words, I guess  ...  Positive  Positive
#
#    TB_Polarity  VD_Polarity    neg
# 0     0.144514      -0.9618  0.110
# 1    -0.083840      -0.9375  0.054
# 2     0.316818       0.9873  0.082
# 3     0.018005      -0.9654  0.161
# 4     0.095136       0.9896  0.086

# %%
df_comp.drop(['lyrics'], axis=1, inplace=True)
merged_df = all_lyrics.join(df_comp)
merged_df.head()
# Out:
#    year  No.            Title                Artist(s)  \
# 0  2003    1     "In da Club"                  50 Cent
# 1  2003    2       "Ignition"                 R. Kelly
# 2  2003    3       "Get Busy"                Sean Paul
# 3  2003    4  "Crazy in Love"  Beyoncé featuring Jay-Z
# 4  2003    5  "When I'm Gone"             3 Doors Down
#
#                                               lyrics  \
# 0     Go, go Go, go, go, go Go, shawty, it's your...
# 1   You remind me of something I just can't think...
# 2   Shake dat ting, miss Cana, Cana Shake dat tin...
# 3   Yes! (Whoo, ow!) So crazy right now Most incr...
# 4   Yeah, it's my life In my own words, I guess  ...
#
#                             genres  \
# 0                          hip hop
# 1
# 2  pop, world/traditional, hip hop
# 3                pop, hip hop, r&b
# 4                       metal, pop
#
#                                            subgenres      time  Textblob  \
# 0  east coast hip hop, gangster rap, hip hop, pop...  03:13:00  Positive
# 1                                                NaN  03:06:00  Negative
# 2                      dance pop, dancehall, pop rap  03:31:00  Positive
# 3  dance pop, pop, r&b, east coast hip hop, hip h...  03:56:00  Positive
# 4  alternative metal, nu metal, pop rock, post-gr...  04:20:00  Positive
#
#       Vader  TB_Polarity  VD_Polarity    neg
# 0  Negative     0.144514      -0.9618  0.110
# 1  Negative    -0.083840      -0.9375  0.054
# 2  Positive     0.316818       0.9873  0.082
# 3  Negative     0.018005      -0.9654  0.161
# 4  Positive     0.095136       0.9896  0.086

# %%
# calculate count of each genre
genres_list = ['pop', 'hip hop', 'rock', 'latin', 'dance/electronic', 'r&b', 'country', 
               'folk/acoustic', 'metal', 'jazz', 'easy listening', 'blues', 'world/traditional']

genre_counts = [merged_df['genres'].str.contains(g).sum() for g in genres_list]

genre_count_dict = dict(zip(genres_list, genre_counts))
genre_count_dict = dict(sorted(genre_count_dict.items(), key=lambda x: x[1], reverse=True))

for key, value in genre_count_dict.items():
    print(f"{key}: {value}")
print('\nSum: ', sum(genre_counts), sep='')
# Out:
# pop: 1427
# hip hop: 913
# r&b: 545
# country: 210
# rock: 152
# folk/acoustic: 134
# dance/electronic: 133
# metal: 67
# latin: 57
# world/traditional: 29
# easy listening: 18
# blues: 10
# jazz: 2
#
# Sum: 3697

# %%
a = merged_df[merged_df['genres'].str.contains('world/traditional')]
a['TB_Polarity'].describe()
# Out:
# count    29.000000
# mean      0.176388
# std       0.183263
# min      -0.098958
# 25%       0.081852
# 50%       0.156250
# 75%       0.282791
# max       0.750000
# Name: TB_Polarity, dtype: float64

# %%
# sentiment score for all genres from the past 20 years
genres_mean = {}

# genres_list = ['pop', 'hip hop', 'rock', 'latin', 'dance/electronic', 'r&b', 'country', 
#                'folk/acoustic', 'metal', 'jazz', 'easy listening', 'blues', 'world/traditional']

for genre in genres_list:
    genre_df = merged_df[merged_df['genres'].str.contains(genre)]
    genre_polarity = genre_df['TB_Polarity'].mean()
    std = genre_df['TB_Polarity'].std()
    number = merged_df['genres'].str.contains(genre).sum()
    genres_mean[genre] = (genre_polarity, number, std)


sorted_genres = dict(sorted(genres_mean.items(), key=lambda x: x[1], reverse=True))

genres_sentiment_df = pd.DataFrame.from_dict(sorted_genres, orient='index')
genres_sentiment_df.rename(columns={0:'Average Sentiment Score', 1:'Count', 2: 'STD'}, inplace=True)
display(genres_sentiment_df)
genres_sentiment_df.to_csv('data/RQ1/genres_sentiment.csv')
# Out:
#                    Average Sentiment Score  Count       STD
# world/traditional                 0.176388     29  0.183263
# easy listening                    0.167961     18  0.149410
# jazz                              0.148346      2  0.273340
# folk/acoustic                     0.110295    134  0.175103
# dance/electronic                  0.092778    133  0.198814
# metal                             0.092507     67  0.174314
# r&b                               0.088660    545  0.161038
# pop                               0.087315   1427  0.173498
# country                           0.079891    210  0.149796
# rock                              0.078955    152  0.162191
# blues                             0.078430     10  0.116395
# hip hop                           0.072200    913  0.158345
# latin                             0.069911     57  0.225827

# %%
# keeping only the songs that belong to the three genres
keep = ['pop', 'hip hop', 'r&b']
select_genre_df = merged_df[merged_df.genres.fillna('').str.contains('|'.join(keep))]
select_genre_df.drop(['No.', 'Artist(s)', 'Title', 'subgenres', 'time'], axis=1, inplace=True)
display(select_genre_df)
# Out:
#       year                                             lyrics  \
# 0     2003     Go, go Go, go, go, go Go, shawty, it's your...
# 2     2003   Shake dat ting, miss Cana, Cana Shake dat tin...
# 3     2003   Yes! (Whoo, ow!) So crazy right now Most incr...
# 4     2003   Yeah, it's my life In my own words, I guess  ...
# 5     2003   All day Starin' at the ceilin', makin' Friend...
# ...    ...                                                ...
# 1989  2022   We hug and, yes, we make love And always just...
# 1990  2022   She don't like it, catching cabs downtown The...
# 1993  2022   (Ooh, ooh-ooh, ooh-ooh) (Ooh, ooh-ooh, ooh-oo...
# 1997  2022   Mummy don't know Daddy's getting hot At the B...
# 1999  2022   I swear I don't know how I trusted A Montero ...
#
#                                genres  Textblob     Vader  TB_Polarity  \
# 0                             hip hop  Positive  Negative     0.144514
# 2     pop, world/traditional, hip hop  Positive  Positive     0.316818
# 3                   pop, hip hop, r&b  Positive  Negative     0.018005
# 4                          metal, pop  Positive  Positive     0.095136
# 5           folk/acoustic, pop, metal  Positive  Positive     0.082143
# ...                               ...       ...       ...          ...
# 1989                         pop, r&b  Positive  Positive     0.171171
# 1990      country, folk/acoustic, pop  Positive  Positive     0.026492
# 1993                              pop  Negative  Negative    -0.354428
# 1997                              pop  Positive  Positive     0.053283
# 1999                     country, pop  Negative  Positive    -0.011216
#
#       VD_Polarity    neg
# 0         -0.9618  0.110
# 2          0.9873  0.082
# 3         -0.9654  0.161
# 4          0.9896  0.086
# 5          0.9396  0.041
# ...           ...    ...
# 1989       0.9953  0.062
# 1990       0.9855  0.078
# 1993      -0.9959  0.180
# 1997       0.9911  0.021
# 1999       0.9706  0.047
#
# [1708 rows x 8 columns]

# %%
# all songs from the three chosen genres
years = list(range(2003, 2023))

pop_dict = {}
hip_dict = {}
rb_dict = {}

for year in years:
    year_df = select_genre_df[select_genre_df['year'] == year]
    pop_df = year_df[year_df['genres'].str.contains('pop')]
    hip_df = year_df[year_df['genres'].str.contains('hip hop')]
    rb_df = year_df[year_df['genres'].str.contains('r&b')]
    
    pop_dict[year] = pop_df
    hip_dict[year] = hip_df
    rb_dict[year] = rb_df

# %%
# Average score of the top three genres by year
avg_dict = {}

for genre_dict, genre_name in zip([pop_dict, hip_dict, rb_dict], ['pop', 'hip hop', 'r&b']):
    genre_avg_dict = {}
    
    for year in range(2003, 2023):
        year_genre_df = select_genre_df[(select_genre_df['year'] == year) & (select_genre_df['genres'].str.contains(genre_name))]
        avg_polarity = year_genre_df['TB_Polarity'].mean()
        genre_avg_dict[year] = avg_polarity
    
    avg_dict[genre_name] = genre_avg_dict

# %%
# Average sentiment score for each year
all_mean = {}

for year in range(2003, 2023):
    year_df = merged_df[merged_df['year'] == year]
    avg_polarity = year_df['TB_Polarity'].mean()
    all_mean[year] = avg_polarity

all_pol = {'All': all_mean}

# %%
avg_dict.update(all_pol)
genre_year_df = pd.DataFrame.from_dict(avg_dict, orient='index').T
genre_year_df.to_csv('data/RQ1/genre_year.csv')
genre_year_df.style.background_gradient(cmap='PiYG')
# Out:
# <style type="text/css">
# #T_64477_row0_col0 {
#   background-color: #edf6e1;
#   color: #000000;
# }
# #T_64477_row0_col1 {
#   background-color: #9acd61;
#   color: #000000;
# }
# #T_64477_row0_col2 {
#   background-color: #fbd8eb;
#   color: #000000;
# }
# #T_64477_row0_col3 {
#   background-color: #acd977;
#   color: #000000;
# }
# #T_64477_row1_col0 {
#   background-color: #d9f0bc;
#   color: #000000;
# }
# #T_64477_row1_col1 {
#   background-color: #93c959;
#   color: #000000;
# }
# #T_64477_row1_col2 {
#   background-color: #f8d0e7;
#   color: #000000;
# }
# #T_64477_row1_col3, #T_64477_row18_col1, #T_64477_row18_col3 {
#   background-color: #ebf6dc;
#   color: #000000;
# }
# #T_64477_row2_col0 {
#   background-color: #f2b8db;
#   color: #000000;
# }
# #T_64477_row2_col1 {
#   background-color: #9ccf64;
#   color: #000000;
# }
# #T_64477_row2_col2 {
#   background-color: #fad4e9;
#   color: #000000;
# }
# #T_64477_row2_col3 {
#   background-color: #fde0ef;
#   color: #000000;
# }
# #T_64477_row3_col0 {
#   background-color: #f9eef4;
#   color: #000000;
# }
# #T_64477_row3_col1 {
#   background-color: #3f811e;
#   color: #f1f1f1;
# }
# #T_64477_row3_col2, #T_64477_row11_col3, #T_64477_row14_col1 {
#   background-color: #faebf3;
#   color: #000000;
# }
# #T_64477_row3_col3 {
#   background-color: #fbe9f2;
#   color: #000000;
# }
# #T_64477_row4_col0 {
#   background-color: #bbe28a;
#   color: #000000;
# }
# #T_64477_row4_col1 {
#   background-color: #66a731;
#   color: #f1f1f1;
# }
# #T_64477_row4_col2 {
#   background-color: #a1d26a;
#   color: #000000;
# }
# #T_64477_row4_col3, #T_64477_row5_col0, #T_64477_row8_col3 {
#   background-color: #8fc654;
#   color: #000000;
# }
# #T_64477_row5_col1, #T_64477_row6_col2, #T_64477_row7_col3, #T_64477_row10_col0 {
#   background-color: #276419;
#   color: #f1f1f1;
# }
# #T_64477_row5_col2, #T_64477_row9_col1 {
#   background-color: #dff2c4;
#   color: #000000;
# }
# #T_64477_row5_col3 {
#   background-color: #34741c;
#   color: #f1f1f1;
# }
# #T_64477_row6_col0 {
#   background-color: #e1f3c7;
#   color: #000000;
# }
# #T_64477_row6_col1 {
#   background-color: #2d6b1a;
#   color: #f1f1f1;
# }
# #T_64477_row6_col3, #T_64477_row18_col0 {
#   background-color: #c2e596;
#   color: #000000;
# }
# #T_64477_row7_col0 {
#   background-color: #4e9322;
#   color: #f1f1f1;
# }
# #T_64477_row7_col1 {
#   background-color: #397a1d;
#   color: #f1f1f1;
# }
# #T_64477_row7_col2 {
#   background-color: #b5df82;
#   color: #000000;
# }
# #T_64477_row8_col0, #T_64477_row9_col2 {
#   background-color: #d2ecb0;
#   color: #000000;
# }
# #T_64477_row8_col1 {
#   background-color: #c0e593;
#   color: #000000;
# }
# #T_64477_row8_col2, #T_64477_row17_col1 {
#   background-color: #f9eff4;
#   color: #000000;
# }
# #T_64477_row9_col0 {
#   background-color: #eff6e5;
#   color: #000000;
# }
# #T_64477_row9_col3, #T_64477_row14_col2 {
#   background-color: #dbf0bf;
#   color: #000000;
# }
# #T_64477_row10_col1 {
#   background-color: #498d20;
#   color: #f1f1f1;
# }
# #T_64477_row10_col2 {
#   background-color: #cdeaa7;
#   color: #000000;
# }
# #T_64477_row10_col3 {
#   background-color: #589b28;
#   color: #f1f1f1;
# }
# #T_64477_row11_col0, #T_64477_row19_col3 {
#   background-color: #fce4f0;
#   color: #000000;
# }
# #T_64477_row11_col1 {
#   background-color: #e4f4cd;
#   color: #000000;
# }
# #T_64477_row11_col2 {
#   background-color: #f6f7f5;
#   color: #000000;
# }
# #T_64477_row12_col0 {
#   background-color: #fcdbed;
#   color: #000000;
# }
# #T_64477_row12_col1 {
#   background-color: #c6e79c;
#   color: #000000;
# }
# #T_64477_row12_col2 {
#   background-color: #f4bfdf;
#   color: #000000;
# }
# #T_64477_row12_col3 {
#   background-color: #fbe7f2;
#   color: #000000;
# }
# #T_64477_row13_col0, #T_64477_row19_col2 {
#   background-color: #eba1cb;
#   color: #000000;
# }
# #T_64477_row13_col1 {
#   background-color: #ebf6db;
#   color: #000000;
# }
# #T_64477_row13_col2 {
#   background-color: #dd73ac;
#   color: #f1f1f1;
# }
# #T_64477_row13_col3 {
#   background-color: #f7cbe4;
#   color: #000000;
# }
# #T_64477_row14_col0 {
#   background-color: #b9e187;
#   color: #000000;
# }
# #T_64477_row14_col3 {
#   background-color: #f9f1f5;
#   color: #000000;
# }
# #T_64477_row15_col0 {
#   background-color: #aa0e68;
#   color: #f1f1f1;
# }
# #T_64477_row15_col1, #T_64477_row15_col2, #T_64477_row15_col3, #T_64477_row16_col0 {
#   background-color: #8e0152;
#   color: #f1f1f1;
# }
# #T_64477_row16_col1 {
#   background-color: #eca6cf;
#   color: #000000;
# }
# #T_64477_row16_col2 {
#   background-color: #d34f99;
#   color: #f1f1f1;
# }
# #T_64477_row16_col3 {
#   background-color: #b51370;
#   color: #f1f1f1;
# }
# #T_64477_row17_col0 {
#   background-color: #e9f5d6;
#   color: #000000;
# }
# #T_64477_row17_col2 {
#   background-color: #e692c1;
#   color: #000000;
# }
# #T_64477_row17_col3 {
#   background-color: #f8f5f6;
#   color: #000000;
# }
# #T_64477_row18_col2, #T_64477_row19_col0 {
#   background-color: #faecf3;
#   color: #000000;
# }
# #T_64477_row19_col1 {
#   background-color: #6bac34;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_64477">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_64477_level0_col0" class="col_heading level0 col0" >pop</th>
#       <th id="T_64477_level0_col1" class="col_heading level0 col1" >hip hop</th>
#       <th id="T_64477_level0_col2" class="col_heading level0 col2" >r&b</th>
#       <th id="T_64477_level0_col3" class="col_heading level0 col3" >All</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_64477_level0_row0" class="row_heading level0 row0" >2003</th>
#       <td id="T_64477_row0_col0" class="data row0 col0" >0.088982</td>
#       <td id="T_64477_row0_col1" class="data row0 col1" >0.083506</td>
#       <td id="T_64477_row0_col2" class="data row0 col2" >0.079589</td>
#       <td id="T_64477_row0_col3" class="data row0 col3" >0.097870</td>
#     </tr>
#     <tr>
#       <th id="T_64477_level0_row1" class="row_heading level0 row1" >2004</th>
#       <td id="T_64477_row1_col0" class="data row1 col0" >0.096085</td>
#       <td id="T_64477_row1_col1" class="data row1 col1" >0.084949</td>
#       <td id="T_64477_row1_col2" class="data row1 col2" >0.077571</td>
#       <td id="T_64477_row1_col3" class="data row1 col3" >0.083725</td>
#     </tr>
#     <tr>
#       <th id="T_64477_level0_row2" class="row_heading level0 row2" >2005</th>
#       <td id="T_64477_row2_col0" class="data row2 col0" >0.063687</td>
#       <td id="T_64477_row2_col1" class="data row2 col1" >0.083028</td>
#       <td id="T_64477_row2_col2" class="data row2 col2" >0.078962</td>
#       <td id="T_64477_row2_col3" class="data row2 col3" >0.068390</td>
#     </tr>
#     <tr>
#       <th id="T_64477_level0_row3" class="row_heading level0 row3" >2006</th>
#       <td id="T_64477_row3_col0" class="data row3 col0" >0.079020</td>
#       <td id="T_64477_row3_col1" class="data row3 col1" >0.106982</td>
#       <td id="T_64477_row3_col2" class="data row3 col2" >0.087766</td>
#       <td id="T_64477_row3_col3" class="data row3 col3" >0.071945</td>
#     </tr>
#     <tr>
#       <th id="T_64477_level0_row4" class="row_heading level0 row4" >2007</th>
#       <td id="T_64477_row4_col0" class="data row4 col0" >0.102858</td>
#       <td id="T_64477_row4_col1" class="data row4 col1" >0.095703</td>
#       <td id="T_64477_row4_col2" class="data row4 col2" >0.123575</td>
#       <td id="T_64477_row4_col3" class="data row4 col3" >0.102561</td>
#     </tr>
#     <tr>
#       <th id="T_64477_level0_row5" class="row_heading level0 row5" >2008</th>
#       <td id="T_64477_row5_col0" class="data row5 col0" >0.110697</td>
#       <td id="T_64477_row5_col1" class="data row5 col1" >0.114913</td>
#       <td id="T_64477_row5_col2" class="data row5 col2" >0.108469</td>
#       <td id="T_64477_row5_col3" class="data row5 col3" >0.120089</td>
#     </tr>
#     <tr>
#       <th id="T_64477_level0_row6" class="row_heading level0 row6" >2009</th>
#       <td id="T_64477_row6_col0" class="data row6 col0" >0.094357</td>
#       <td id="T_64477_row6_col1" class="data row6 col1" >0.112534</td>
#       <td id="T_64477_row6_col2" class="data row6 col2" >0.154958</td>
#       <td id="T_64477_row6_col3" class="data row6 col3" >0.094003</td>
#     </tr>
#     <tr>
#       <th id="T_64477_level0_row7" class="row_heading level0 row7" >2010</th>
#       <td id="T_64477_row7_col0" class="data row7 col0" >0.123186</td>
#       <td id="T_64477_row7_col1" class="data row7 col1" >0.108619</td>

# %%
print(merged_df['TB_Polarity'].describe())
all_range = merged_df['TB_Polarity'].describe()[7] - merged_df['TB_Polarity'].describe()[3]
print(all_range)
# Out:
# count    2000.000000
# mean        0.082474
# std         0.168582
# min        -0.700000
# 25%        -0.021370
# 50%         0.071078
# 75%         0.184148
# max         0.764229
# Name: TB_Polarity, dtype: float64
# 1.464229009983727
